# %% [markdown]
# <a href="https://colab.research.google.com/github/kanojiashivi23/-statistics-assignment-using-markdown/blob/main/forandwhileloop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Concept
#for loop -Known count , for i in range()
#while loop- Condition-based,while <condition>
#break-Stop earty,Exit loop
#continue - skip one cycle,Go to next iteration
#pass- placeholder,No action
#do-while (simulated)- Run at least once , while True + break



#FOR LOOP
#for loop is used when you know how exactly you want to repeat something. It iterates over a sequence such as string, list or range of number

# %%
for i in range (5):
     print("iteration:",i)
# Out:
# iteration: 0
# iteration: 1
# iteration: 2
# iteration: 3
# iteration: 4

# %%
for i in range(2,11,2):
     print(i)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
fruits =("Apple","Banana","Cherry")
for f in fruits:
     print("I Like",f)
# Out:
# I Like Apple
# I Like Banana
# I Like Cherry

# %%
total= 0
for i in range(1,6):
     total += i
     print("total:",total)
print ("sum =",total)
# Out:
# total: 1
# total: 3
# total: 6
# total: 10
# total: 15
# sum = 15

# %%
num= 7
for i in range(1,11):
    print(f"{num}x{i}={num*i}")
# Out:
# 7x1=7
# 7x2=14
# 7x3=21
# 7x4=28
# 7x5=35
# 7x6=42
# 7x7=49
# 7x8=56
# 7x9=63
# 7x10=70

# %%
for ch in "Python":
  print (ch, end = "")
# Out:
# Python

# %%
for ch in "Python":
  print (ch)
# Out:
# P
# y
# t
# h
# o
# n

# %%
marks=[40,75,33,90,65]
for m in marks:
    if m>=50:
        print("pass:",m)
# Out:
# pass: 75
# pass: 90
# pass: 65

# %%
#while loop concept
# while loop repeat a book as long as a condition is true.Used when yoy dont know in advance how many times is the loop

# %%
i=1
while i <= 5:
  print(i)
  i +=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
n= 5
while n>0:
  print(n)
  n-= 1
print("Blast off")
# Out:
# 5
# 4
# 3
# 2
# 1
# Blast off

# %%
attempts= 0
password = "python"

while attempts<3:
    guess = input("enter password:")
    if guess== password:
      print("access granted!")
      break
    else:
        print("wrong password.")
        attempts+=1
# Out:
# enter password:python2
# wrong password.
# enter password:python1
# wrong password.
# enter password:python
# access granted!

# %%
i=1
while i<= 10:
   if i%2 == 0:
      print(i)
   i+=1
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
secret= 7
guess=0
while guess != secret:
  guess= int(input("guess number:"))
print("correct!")
# Out:
# guess number:2
# guess number:4
# guess number:6
# guess number:7
# correct!

# %%
num =1
total=0
while num<= 10:
     print(num)
     total+= num
     print("total:",num)
     num+= 1
print ("sum=",total)
# Out:
# 1
# total: 1
# 2
# total: 2
# 3
# total: 3
# 4
# total: 4
# 5
# total: 5
# 6
# total: 6
# 7
# total: 7
# 8
# total: 8
# 9
# total: 9
# 10
# total: 10
# sum= 55

# %%
for i in range (1,10):
    if i == 6:
      break
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range (1,7):
    if i==3:
      continue
    print(i)
# Out:
# 1
# 2
# 4
# 5
# 6
